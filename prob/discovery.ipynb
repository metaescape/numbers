# %%
# %reload_ext autoreload
# %autoreload 2
from sparsity import get_imap_samples, minimal_imap,plot_graph

# %%
imap_samples = get_imap_samples()
print(imap_samples.shape)
# Out:
# (10000, 5)

# %%
p_a = [1, 2, 3, 4, 5]

g = minimal_imap(imap_samples, p_a, 0.05)

plot_graph(g)

# %%
p_b = [5, 4, 1, 2, 3]

g = minimal_imap(imap_samples, p_b, 0.05)

plot_graph(g)

# %%
p_c = [5, 4, 3, 2, 1]

g = minimal_imap(imap_samples, p_c, 0.05)

plot_graph(g)

# %%
from search_mec import load_graphs
gs = load_graphs()
plot_graph(gs[0][0]), plot_graph(gs[0][1])
# Out:
# (None, None)
